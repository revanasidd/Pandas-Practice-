# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from pandas import read_csv

# %%
import pandas as pd
import numpy as np
dz=pd.read_csv("daily_sale_report_84784203.csv")

# %%
dz.head()
# Out:
#          DATE  TOTAL BILLS             INVOICE RANGE  TOTAL TAXABLE AMOUNT  \
# 0  25-12-2020           67  G/2021/3665, G/2021/3699              17875.23
# 1  24-12-2020          100  G/2021/3599, A/2021/6435              24122.00
# 2  23-12-2020          118  G/2021/3509, A/2021/6401              26827.98
# 3  22-12-2020          141  G/2021/3404, G/2021/3508              29246.64
# 4  21-12-2020          150  G/2021/3305, A/2021/6338              29055.02
#
#    TOTAL TAX AMOUNT  Taxable Amount 0%  Taxable Amount 3%  Taxable Amount 5%  \
# 0           2179.93           10401.93              14.27            5832.38
# 1           3126.83            9604.36             145.05            7294.44
# 2           3436.34           10704.62              29.13            8757.29
# 3           3819.97           11457.22              14.27            8308.39
# 4           3553.37           17199.15               0.00           10623.76
#
# ...

# %%
dz.drop(25,inplace=True)

# %%
dz.isna().sum()
# Out:
# DATE                       0
# TOTAL BILLS                0
# INVOICE RANGE              0
# TOTAL TAXABLE AMOUNT       0
# TOTAL TAX AMOUNT           0
# Taxable Amount 0%          0
# Taxable Amount 3%          0
# Taxable Amount 5%          0
# Taxable Amount 12%         0
# Taxable Amount 18%         0
# Taxable Amount 28%         0
# TOTAL CESS AMOUNT          0
# TOTAL ADDL CESS AMOUNT     0
# TOTAL AMOUNT               0
# CASH                       0
# CARD                       0
# OTHER MODES                0
# AMOUNT RETURN              0
# AMOUNT RETURN TO CREDIT    0
# TOTAL ITEMS SOLD           0
# TOTAL QTY                  0
# RETURNED ITEMS COUNT       0
# RETURNED QTY               0
# dtype: int64

# %%
df=dz[['DATE','TOTAL BILLS','TOTAL AMOUNT']]
df
# Out:
#           DATE  TOTAL BILLS  TOTAL AMOUNT
# 0   25-12-2020           67       30458.0
# 1   24-12-2020          100       36861.0
# 2   23-12-2020          118       40972.0
# 3   22-12-2020          141       44526.0
# 4   21-12-2020          150       49809.0
# 5   20-12-2020          379      107695.0
# 6   19-12-2020          258       65804.0
# 7   18-12-2020          136       50934.0
# 8   17-12-2020          125       41256.0
# 9   16-12-2020          134       36868.0
# 10  15-12-2020          170       44881.0
# 11  14-12-2020          147       40033.0
# 12  13-12-2020          402      110708.0
# 13  12-12-2020          228       69633.0
# 14  11-12-2020          100       33646.0
# 15  10-12-2020          132       60358.0
# 16  09-12-2020          107       40098.0
# 17  08-12-2020          120       44959.0
# 18  07-12-2020          137       41672.0
# 19  06-12-2020          144       59081.0
# 20  05-12-2020          114       41494.0
# ...

# %%
df.to_csv('one_month_sale.csv')
one_month_sale=pd.read_csv('one_month_sale.csv')

# %%
one_month_sale['BASKET_VALUE']=(one_month_sale['TOTAL AMOUNT']/one_month_sale['TOTAL BILLS'])

# %%
one_month_sale
# Out:
#     Unnamed: 0        DATE  TOTAL BILLS  TOTAL AMOUNT  BASKET_VALUE
# 0            0  25-12-2020           67       30458.0    454.597015
# 1            1  24-12-2020          100       36861.0    368.610000
# 2            2  23-12-2020          118       40972.0    347.220339
# 3            3  22-12-2020          141       44526.0    315.787234
# 4            4  21-12-2020          150       49809.0    332.060000
# 5            5  20-12-2020          379      107695.0    284.155673
# 6            6  19-12-2020          258       65804.0    255.054264
# 7            7  18-12-2020          136       50934.0    374.514706
# 8            8  17-12-2020          125       41256.0    330.048000
# 9            9  16-12-2020          134       36868.0    275.134328
# 10          10  15-12-2020          170       44881.0    264.005882
# 11          11  14-12-2020          147       40033.0    272.333333
# 12          12  13-12-2020          402      110708.0    275.393035
# ...

# %%
one_month_sale.columns
# Out:
# Index(['Unnamed: 0', 'DATE', 'TOTAL BILLS', 'TOTAL AMOUNT', 'BASKET_VALUE'], dtype='object')

# %%
one_month_sale.drop(columns='Unnamed: 0',inplace=True)

# %%
one_month_sale.fillna('Totales',inplace=True)

# %%
one_month_sale
# Out:
#           DATE  TOTAL BILLS  TOTAL AMOUNT  BASKET_VALUE
# 0   25-12-2020           67       30458.0    454.597015
# 1   24-12-2020          100       36861.0    368.610000
# 2   23-12-2020          118       40972.0    347.220339
# 3   22-12-2020          141       44526.0    315.787234
# 4   21-12-2020          150       49809.0    332.060000
# 5   20-12-2020          379      107695.0    284.155673
# 6   19-12-2020          258       65804.0    255.054264
# 7   18-12-2020          136       50934.0    374.514706
# 8   17-12-2020          125       41256.0    330.048000
# 9   16-12-2020          134       36868.0    275.134328
# 10  15-12-2020          170       44881.0    264.005882
# 11  14-12-2020          147       40033.0    272.333333
# 12  13-12-2020          402      110708.0    275.393035
# 13  12-12-2020          228       69633.0    305.407895
# 14  11-12-2020          100       33646.0    336.460000
# 15  10-12-2020          132       60358.0    457.257576
# ...

# %%
one_month_sale.drop(25,inplace=True)

# %%
one_month_sale[['BASKET_VALUE','DATE']].max()
# Out:
# BASKET_VALUE    552.759
# DATE            Totales
# dtype: object

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')
one_month_sale.plot(kind='bar',
                    x='DATE',
                    y='BASKET_VALUE',
                    figsize=(15,9),title='DailyZone month Sale Dec 2020');

# %% [markdown]
# ### Describing the Data

# %%
from collections import Counter

# %%
Cash=np.array(mr['CASH'][0:31])
Cash
# Out:
# array([47484, 57804, 55577, 31634, 27730, 42510, 49254, 37371, 47395,
#        61754, 73747, 81477, 65153, 44317, 50501, 70148, 55000, 43671,
#        45863, 53142, 60270, 63007, 56010, 72913, 45156, 55834, 55444,
#        32355, 44567, 72399, 83003], dtype=int64)

# %%
print('The Mean Of Cash',Cash.mean())
print('The Mean Of min',Cash.min())
print('The Mean Of max',Cash.max())
print('The Mean Of std',Cash.std())
print('The Mean Of var',Cash.var())
print()
print('The 25% Of Cash',np.percentile(Cash,25))
print('The median% Of Cash',np.median(Cash))
print('The 75% Of Cash',np.percentile(Cash,75))
# Out:
# The Mean Of Cash 54273.87096774193
# The Mean Of min 27730
# The Mean Of max 83003
# The Mean Of std 13791.074691431448
# The Mean Of var 190193741.144641
#
# The 25% Of Cash 44861.5
# The median% Of Cash 55000.0
# The 75% Of Cash 62380.5

# %%
sns.set()
plt.hist(Cash)
plt.show()

# %%
plt.plot(mr.CASH,label='Cash')
plt.plot(mr.CARD,label='Card')
plt.legend()

# %%
import random
def guess():
    gess=''
    n=random.randint(1,10)
    while gess!=n:
        gess=int(input("Your try:"))
        if gess>n:
            print('Its too High')
        if gess<n:
            print('its too low')
    print('You won')
guess()
# Out:
# Your try:1
# its too low
# Your try:3
# its too low
# Your try:4
# its too low
# Your try:8
# its too low
# Your try:9
# You won

# %%
n=random.randint(1,10)
n
# Out:
# 3
